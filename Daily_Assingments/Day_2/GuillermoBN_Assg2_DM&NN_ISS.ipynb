# %% [markdown]
# # Data Mining and Neural Networks
# ## Practical Session 1
# Designed by Wilmer Garzón, last updated: 26-June-2025
# <br><br>Completed by Guillermo Blanco Núñez on July 15th, 2025
# ## Objective
# In this session, we will practice the following topics:
# - Introduction to Python and Jupyter
# - Loading data with pandas
# - Basic data visualization with seaborn
# - Data normalization with sklearn
#
# Let's get started!

# %% [markdown]
# ### 1. Loading Data with pandas
# We will start by loading a sample dataset using pandas.

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('test.csv')

# Display the first few rows
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### 2. Basic Data Visualization with seaborn
# We will create a simple bar plot to visualize the data.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot
sns.barplot(x='PassengerId', y='Age', data=data)
plt.show()

# %% [markdown]
# ### 3. Data Normalization with sklearn
# We will normalize the 'Value' column using MinMaxScaler.

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the data
data['Normalized_Value'] = scaler.fit_transform(data[['Fare']])

# Display the first few rows
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Normalized_Value
# 0  34.5      0      0   330911   7.8292   NaN        Q          0.015282
# 1  47.0      1      0   363272   7.0000   NaN        S          0.013663
# 2  62.0      0      0   240276   9.6875   NaN        Q          0.018909
# 3  27.0      0      0   315154   8.6625   NaN        S          0.016908
# 4  22.0      1      1  3101298  12.2875   NaN        S          0.023984

# %% [markdown]
# ## Exercises
# Now it's your turn! Complete the following exercises to practice what you've learned.

# %% [markdown]
# ### Exercise 1: Load a New Dataset
# Load the dataset 'new_data.csv' and display the first few rows.

# %%
import pandas as pd
divo_data = pd.read_csv('divorce.csv', sep = ';')
divo_data.head()
# Out:
#    Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  Atr7  Atr8  Atr9  Atr10  ...  Atr46  \
# 0     2     2     4     1     0     0     0     0     0      0  ...      2
# 1     4     4     4     4     4     0     0     4     4      4  ...      2
# 2     2     2     2     2     1     3     2     1     1      2  ...      3
# 3     3     2     3     2     3     3     3     3     3      3  ...      2
# 4     2     2     1     1     1     1     0     0     0      0  ...      2
#
#    Atr47  Atr48  Atr49  Atr50  Atr51  Atr52  Atr53  Atr54  Class
# 0      1      3      3      3      2      3      2      1      1
# 1      2      3      4      4      4      4      2      2      1
# 2      2      3      1      1      1      2      2      2      1
# 3      2      3      3      3      3      2      2      2      1
# 4      1      2      3      2      2      2      1      0      1
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Exercise 2: Calculate Descriptive Statistics
# Calculate and display the descriptive statistics for the new dataset.

# %%
divo_data.describe()
# Out:
#              Atr1        Atr2        Atr3        Atr4        Atr5        Atr6  \
# count  170.000000  170.000000  170.000000  170.000000  170.000000  170.000000
# mean     1.776471    1.652941    1.764706    1.482353    1.541176    0.747059
# std      1.627257    1.468654    1.415444    1.504327    1.632169    0.904046
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      2.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 75%      3.000000    3.000000    3.000000    3.000000    3.000000    1.000000
# max      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
#
#              Atr7        Atr8        Atr9       Atr10  ...       Atr46  \
# count  170.000000  170.000000  170.000000  170.000000  ...  170.000000
# mean     0.494118    1.452941    1.458824    1.576471  ...    2.552941
# ...

# %% [markdown]
# ### Exercise 3: Create a Bar Plot
# Create a bar plot to visualize the 'Category' and 'Value' columns in the new dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot
sns.barplot(x='Atr5', y='Atr23', data=divo_data)
plt.xlabel("Quality of time spent together")
plt.ylabel("Knowing of wife´sfavourite food")
plt.show()

# %% [markdown]
# This graphic visually describes the relation between attribute 5 and attribute 23:
#
# *   Attribute 5:	The time I spent with my wife is special for us.
# *   Attribute 23:	I know my wife's favorite food.
#
#
# The graphic clearly shows that the relation is positively proportional, as the quality of the time spent together increases so does the amount of partners that know their wife´s favourite food.

# %% [markdown]
# ### Exercise 4: Normalize a New Column
# Normalize the 'Value' column in the new dataset using MinMaxScaler.

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the scaler
scaler = MinMaxScaler()

# Fit and transform the data
divo_data['Normalized_Value'] = scaler.fit_transform(divo_data[['Atr23']])

# Display the first few rows
divo_data.head()
# Out:
#    Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  Atr7  Atr8  Atr9  Atr10  ...  Atr47  \
# 0     2     2     4     1     0     0     0     0     0      0  ...      1
# 1     4     4     4     4     4     0     0     4     4      4  ...      2
# 2     2     2     2     2     1     3     2     1     1      2  ...      2
# 3     3     2     3     2     3     3     3     3     3      3  ...      2
# 4     2     2     1     1     1     1     0     0     0      0  ...      1
#
#    Atr48  Atr49  Atr50  Atr51  Atr52  Atr53  Atr54  Class  Normalized_Value
# 0      3      3      3      2      3      2      1      1              0.00
# 1      3      4      4      4      4      2      2      1              0.00
# 2      3      1      1      1      2      2      2      1              0.25
# 3      3      3      3      3      2      2      2      1              0.25
# 4      2      3      2      2      2      1      0      1              0.00
#
# [5 rows x 56 columns]

# %% [markdown]
# Exercise 5: Adding Missing Values
#
#
# *   If your dataset does not contain missing values, add 10% missing values.
# *   Display the missing value information both **descriptively** and **visually** per each column.

# %%
import numpy as np
import missingno as msno

NEW_divo_data = divo_data.copy()
for _ in range(int(divo_data.size * 0.10)):
    row = np.random.randint(0, data.shape[0])
    col = np.random.randint(0, data.shape[1])
    NEW_divo_data.iat[row, col] = np.nan


#Result display
#Descriptive
print("Descriptive display fo the missing value information:\n")
print(NEW_divo_data.isnull().sum())

#Visual
print("\n\n\n Visually display fo the missing value information:\n")
NEW_divo_data.isnull().sum().plot(kind='bar', color='red', figsize = (10, 5))
plt.title("Null values per attribute")
plt.ylabel("Number of null values")
plt.xlabel("Attributes")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Descriptive display fo the missing value information:
#
# Atr1     16
# Atr2      8
# Atr3     13
# Atr4     13
# Atr5     14
# Atr6     15
# Atr7     21
# Atr8     19
# Atr9     26
# Atr10    10
# Atr11    17
# Atr12    16
# Atr13    18
# Atr14    16
# Atr15    17
# Atr16    12
# Atr17    14
# Atr18    21
# Atr19    15
# Atr20    12
# Atr21    14
# Atr22    10
# Atr23     9
# Atr24    17
# Atr25    12
# Atr26    24
# Atr27    19
# Atr28    20
# Atr29    15
# Atr30    21
# Atr31    13
# Atr32    21
# Atr33    16
# Atr34    13
# Atr35    15
# Atr36    17
# Atr37    13
# Atr38     9
# Atr39    17
# Atr40    14
# Atr41    19
# Atr42    14
# Atr43    17
# Atr44    21
# Atr45    22
# Atr46    13
# Atr47    19
# Atr48    18
# Atr49    14
# Atr50    15
# Atr51    16
# Atr52    15
# Atr53    20
# Atr54    16
# Class    19
# dtype: int64
#
#
#
#  Visually display fo the missing value information:

# %% [markdown]
# The graphic displays the number of null values each attribute has. Initially in this dataset there are no null values but after adding 10% of null values, these are shown in the dataset. As shown by the graphic, the distribution of this 10% of null values isn´t equitable throughout all the attributes. Although not all attributes have 10% null values, the sum of all the atributes in the dataset amount tom 10% null values.
